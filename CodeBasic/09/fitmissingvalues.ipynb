# %%
# Use other columns to predict the missing column
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
df[['monthly_income', 'cibil_score']] = imputer.fit_transform(
    df[['monthly_income', 'cibil_score']]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 from sklearn.impute import KNNImputer
#       4 imputer = KNNImputer(n_neighbors=5)
#       5 df[['monthly_income', 'cibil_score']] = imputer.fit_transform(
# ----> 6     df[['monthly_income', 'cibil_score']]
#       7 )
#
# NameError: name 'df' is not defined
