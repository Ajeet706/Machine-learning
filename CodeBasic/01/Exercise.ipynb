# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Practical Code\Machine-learning\CodeBasic\Excel_Data\canada_per_capita_income.csv")

# %%
df.shape
# Out:
# (47, 2)

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df = df.rename(columns={'per capita income (US$)':'income'})

# %%
df.head(2)
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935

# %%
sns.scatterplot(x='year',y='income',data=df)
# Out:
# <Axes: xlabel='year', ylabel='income'>

# %%
x = df.drop('income',axis='columns')
y= df['income']

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Exercise
# Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020

# %%
model.predict([[2020]])
# Out:
# C:\Users\ajeet\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
