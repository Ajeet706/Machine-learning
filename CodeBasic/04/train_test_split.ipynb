# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Practical Code\Machine-learning\CodeBasic\Excel_Data\carprice.csv")

# %%
df.shape
# Out:
# (20, 3)

# %%
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.scatterplot(x='Mileage',y='Sell Price($)' , data = df)
plt.show()

# %%
sns.scatterplot(x='Age(yrs)', y='Sell Price($)' , data =  df)
plt.show()

# %%
df.columns
# Out:
# Index(['Mileage', 'Age(yrs)', 'Sell Price($)'], dtype='object')

# %%
x = df[['Mileage','Age(yrs)']].values
y = df['Sell Price($)'].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (14, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1)
# Out:
# LinearRegression(n_jobs=1)

# %%
model.predict(x_test)
# Out:
# array([22451.34756242, 22668.06439958, 38329.70942843, 34976.70876322,
#        14333.9540303 , 26160.77342585])

# %%
model.score(x_test,y_test)
# Out:
# 0.8911199230718782
