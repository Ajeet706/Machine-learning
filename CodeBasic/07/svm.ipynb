# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data , columns=iris.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape
# Out:
# (150, 5)

# %%
df['target'].unique()
# Out:
# array([0, 1, 2])

# %%
df['flower_name'] = df.target.apply(lambda x:iris.target_names[x])

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df['flower_name'].unique()
# Out:
# array([np.str_('setosa'), np.str_('versicolor'), np.str_('virginica')],
#       dtype=object)

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
plt.scatter(df0['sepal length (cm)'],df0['sepal width (cm)'],color='green',marker='+')
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color='red',marker='*')
# plt.scatter(df2['sepal length (cm)'],df2['sepal width (cm)'],color='blue',marker='+')

# %%
plt.scatter(df0['petal length (cm)'],df0['petal width (cm)'],color='green',marker='+')
plt.scatter(df1['petal length (cm)'],df1['petal width (cm)'],color='red',marker='*')
plt.scatter(df2['petal length (cm)'],df2['petal width (cm)'],color='blue',marker='+')

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target', 'flower_name'],
#       dtype='object')

# %%
x = df.drop(['target','flower_name'],axis='columns')
y = df['target']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
x_train.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 138                6.0               3.0                4.8               1.8
# 30                 4.8               3.1                1.6               0.2
# 27                 5.2               3.5                1.5               0.2
# 115                6.4               3.2                5.3               2.3
# 31                 5.4               3.4                1.5               0.4

# %%
model.predict([[6.0,3.0,4.8,1.8]])
# Out:
# C:\Users\ajeet\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model_c = SVC(C=80)
model_c.fit(x_train,y_train)
model_c.score(x_test,y_test)
# Out:
# 1.0

# %%
model_g = SVC(gamma=20)
model_g.fit(x_train,y_train)
model_g.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
model_linear_kernal = SVC(kernel='linear')
model_linear_kernal.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model_linear_kernal.score(x_test,y_test)
# Out:
# 1.0
